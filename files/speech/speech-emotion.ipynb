# %%
import os
from glob import glob
import pickle
import itertools
import numpy as np
from scipy.stats import zscore
from sklearn.model_selection import train_test_split

### Graph imports ###
import matplotlib.pyplot as plt
from PIL import Image
import pandas as pd

### Audio import ###
import librosa
import IPython
from IPython.display import Audio

### Plot imports ###
from IPython.display import Image
import matplotlib.pyplot as plt

### Time Distributed ConvNet imports ###
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Dropout, Activation, TimeDistributed, concatenate
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, BatchNormalization, LeakyReLU, Flatten
from tensorflow.keras.layers import LSTM
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import backend as K
from keras.utils import np_utils
from keras.utils import plot_model
from sklearn.preprocessing import LabelEncoder

### Warning ###
import warnings
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.

# %%
# Audio file path and names
RAV = '/kaggle/input/ravdess-emotional-speech-audio/audio_speech_actors_01-24/'

# %%
dic  =  {1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 8:'surprise'}

# %%
dir_list = os.listdir(RAV)
dir_list.sort()

emotion = []
path = []
for i in dir_list:
    fname = os.listdir(RAV + i)
    for f in fname:
        part = f.split('.')[0].split('-')
        emotion.append(int(part[2]))
        path.append(RAV + i + '/' + f)

RAV_df = pd.DataFrame() 
RAV_df = pd.concat([RAV_df,pd.DataFrame(path, columns = ['path'])],axis=1)

# %%
RAV_df.head()
# Out:
#                                                 path
# 0  /kaggle/input/ravdess-emotional-speech-audio/a...
# 1  /kaggle/input/ravdess-emotional-speech-audio/a...
# 2  /kaggle/input/ravdess-emotional-speech-audio/a...
# 3  /kaggle/input/ravdess-emotional-speech-audio/a...
# 4  /kaggle/input/ravdess-emotional-speech-audio/a...

# %%
signal = []

# Sample rate (16.0 kHz)
sample_rate = 16000     

# Max pad lenght (3.0 sec)
max_pad_len = 49100

for index,path in enumerate(RAV_df.path):
    X, sample_rate = librosa.load(path
                                  ,duration=3
                                  ,offset=0.5
                                 )
    sample_rate = np.array(sample_rate)
    
    y = zscore(X)
        
    # Padding or truncated signal 
    if len(y) < max_pad_len:    
        y_padded = np.zeros(max_pad_len)
        y_padded[:len(y)] = y
        y = y_padded
    elif len(y) > max_pad_len:
        y = np.asarray(y[:max_pad_len])

    # Add to signal list
    signal.append(y)

# %%
labels = np.asarray(emotion).ravel()

# %%
labels.shape
# Out:
# (1440,)

# %%
np.unique(labels)
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
def noisy_signal(signal, snr_low=15, snr_high=30, nb_augmented=2):
    
    # Signal length
    signal_len = len(signal)

    # Generate White noise
    noise = np.random.normal(size=(nb_augmented, signal_len))
    
    # Compute signal and noise power
    s_power = np.sum((signal / (2.0 ** 15)) ** 2) / signal_len
    n_power = np.sum((noise / (2.0 ** 15)) ** 2, axis=1) / signal_len
    
    # Random SNR: Uniform [15, 30]
    snr = np.random.randint(snr_low, snr_high)
    
    # Compute K coeff for each noise
    K = np.sqrt((s_power / n_power) * 10 ** (- snr / 10))
    K = np.ones((signal_len, nb_augmented)) * K
    
    # Generate noisy signal
    return signal + K.T * noise

# %%
print("Data Augmentation: START")
augmented_signal = list(map(noisy_signal, signal))
print("Data Augmentation: END!")
# Out:
# Data Augmentation: START
# Data Augmentation: END!

# %%
def mel_spectrogram(y, sr=16000, n_fft=512, win_length=256, hop_length=128, window='hamming', n_mels=128, fmax=4000):
    
    # Compute spectogram
    mel_spect = np.abs(librosa.stft(y, n_fft=n_fft, window=window, win_length=win_length, hop_length=hop_length)) ** 2
    
    # Compute mel spectrogram
    mel_spect = librosa.feature.melspectrogram(S=mel_spect, sr=sr, n_mels=n_mels, fmax=fmax)
    
    # Compute log-mel spectrogram
    mel_spect = librosa.power_to_db(mel_spect, ref=np.max)
    
    return mel_spect

# %%
mel_spect = np.asarray(list(map(mel_spectrogram, signal)))
augmented_mel_spect = [np.asarray(list(map(mel_spectrogram, augmented_signal[i]))) for i in range(len(augmented_signal))]

# %%
MEL_SPECT_train, MEL_SPECT_test, AUG_MEL_SPECT_train, AUG_MEL_SPECT_test, label_train, label_test = train_test_split(mel_spect, augmented_mel_spect,labels, test_size=0.2,random_state=1)

# Build augmented labels and train
aug_label_train = np.asarray(list(itertools.chain.from_iterable([[label] * 2 for label in label_train])))
AUG_MEL_SPECT_train = np.asarray(list(itertools.chain.from_iterable(AUG_MEL_SPECT_train)))

# Concatenate original and augmented
X_train = np.concatenate((MEL_SPECT_train, AUG_MEL_SPECT_train))
y_train = np.concatenate((label_train, aug_label_train))

# Build test set
X_test = MEL_SPECT_test
y_test = label_test

# %%
X_train.shape
# Out:
# (3456, 128, 384)

# %%
y_train
# Out:
# array([2, 7, 5, ..., 7, 4, 4])

# %%
win_ts = 128
hop_ts = 64

# Split spectrogram into frames
def frame(x, win_step=128, win_size=64):
    nb_frames = 1 + int((x.shape[2] - win_size) / win_step)
    frames = np.zeros((x.shape[0], nb_frames, x.shape[1], win_size)).astype(np.float32)
    for t in range(nb_frames):
        frames[:,t,:,:] = np.copy(x[:,:,(t * win_step):(t * win_step + win_size)]).astype(np.float32)
    return frames

# Frame for TimeDistributed model
X_train = frame(X_train, hop_ts, win_ts)
X_test = frame(X_test, hop_ts, win_ts)

# %%
lb = LabelEncoder()
y_train = np_utils.to_categorical(lb.fit_transform(np.ravel(y_train)))
y_test = np_utils.to_categorical(lb.transform(np.ravel(y_test)))

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1] , X_train.shape[2], X_train.shape[3], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1] , X_test.shape[2], X_test.shape[3], 1)

# %%
K.clear_session()

# Define two sets of inputs: MFCC and FBANK
input_y = Input(shape=X_train.shape[1:], name='Input_MELSPECT')

## First LFLB (local feature learning block)
y = TimeDistributed(Conv2D(64, kernel_size=(3, 3), strides=(1, 1), padding='same'), name='Conv_1_MELSPECT')(input_y)
y = TimeDistributed(BatchNormalization(), name='BatchNorm_1_MELSPECT')(y)
y = TimeDistributed(Activation('elu'), name='Activ_1_MELSPECT')(y)
y = TimeDistributed(MaxPooling2D(pool_size=(2, 2), strides=(2, 2), padding='same'), name='MaxPool_1_MELSPECT')(y)
y = TimeDistributed(Dropout(0.2), name='Drop_1_MELSPECT')(y)     

## Second LFLB (local feature learning block)
y = TimeDistributed(Conv2D(64, kernel_size=(3, 3), strides=(1, 1), padding='same'), name='Conv_2_MELSPECT')(y)
y = TimeDistributed(BatchNormalization(), name='BatchNorm_2_MELSPECT')(y)
y = TimeDistributed(Activation('elu'), name='Activ_2_MELSPECT')(y)
y = TimeDistributed(MaxPooling2D(pool_size=(4, 4), strides=(4, 4), padding='same'), name='MaxPool_2_MELSPECT')(y)
y = TimeDistributed(Dropout(0.2), name='Drop_2_MELSPECT')(y)

## Second LFLB (local feature learning block)
y = TimeDistributed(Conv2D(128, kernel_size=(3, 3), strides=(1, 1), padding='same'), name='Conv_3_MELSPECT')(y)
y = TimeDistributed(BatchNormalization(), name='BatchNorm_3_MELSPECT')(y)
y = TimeDistributed(Activation('elu'), name='Activ_3_MELSPECT')(y)
y = TimeDistributed(MaxPooling2D(pool_size=(4, 4), strides=(4, 4), padding='same'), name='MaxPool_3_MELSPECT')(y)
y = TimeDistributed(Dropout(0.2), name='Drop_3_MELSPECT')(y)

## Second LFLB (local feature learning block)
y = TimeDistributed(Conv2D(128, kernel_size=(3, 3), strides=(1, 1), padding='same'), name='Conv_4_MELSPECT')(y)
y = TimeDistributed(BatchNormalization(), name='BatchNorm_4_MELSPECT')(y)
y = TimeDistributed(Activation('elu'), name='Activ_4_MELSPECT')(y)
y = TimeDistributed(MaxPooling2D(pool_size=(4, 4), strides=(4, 4), padding='same'), name='MaxPool_4_MELSPECT')(y)
y = TimeDistributed(Dropout(0.2), name='Drop_4_MELSPECT')(y)  

## Flat
y = TimeDistributed(Flatten(), name='Flat_MELSPECT')(y)                      
                               
# Apply 2 LSTM layer and one FC
y = LSTM(256, return_sequences=False, dropout=0.2, name='LSTM_1')(y)
y = Dense(y_train.shape[1], activation='softmax', name='FC')(y)

# Build final model
model = Model(inputs=input_y, outputs=y)

# %%
model.compile(optimizer=SGD(lr=0.01, decay=1e-6, momentum=0.8), loss='categorical_crossentropy', metrics=['accuracy'])

# Early stopping
early_stopping = EarlyStopping(monitor='val_acc', patience=30, verbose=1, mode='max')

# Fit model
history = model.fit(X_train, y_train, batch_size=64, epochs=100, validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Train on 3456 samples, validate on 288 samples
# Epoch 1/100
# 3456/3456 [==============================] - 15s 4ms/sample - loss: 2.0833 - accuracy: 0.1502 - val_loss: 2.1361 - val_accuracy: 0.1354
# Epoch 2/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 2.0089 - accuracy: 0.1976 - val_loss: 2.0607 - val_accuracy: 0.1632
# Epoch 3/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.9288 - accuracy: 0.2358 - val_loss: 1.9241 - val_accuracy: 0.2535
# Epoch 4/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.8277 - accuracy: 0.2963 - val_loss: 1.8719 - val_accuracy: 0.2743
# Epoch 5/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.7671 - accuracy: 0.3316 - val_loss: 1.6859 - val_accuracy: 0.3819
# Epoch 6/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.7220 - accuracy: 0.3394 - val_loss: 1.6651 - val_accuracy: 0.3715
# Epoch 7/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.6801 - accuracy: 0.3458 - val_loss: 1.8657 - val_accuracy: 0.2778
# Epoch 8/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.6334 - accuracy: 0.3730 - val_loss: 1.6008 - val_accuracy: 0.3681
# Epoch 9/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.5950 - accuracy: 0.3874 - val_loss: 1.6324 - val_accuracy: 0.3438
# Epoch 10/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.5760 - accuracy: 0.3845 - val_loss: 2.1823 - val_accuracy: 0.2326
# Epoch 11/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.5433 - accuracy: 0.4089 - val_loss: 1.7317 - val_accuracy: 0.3681
# Epoch 12/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.5059 - accuracy: 0.4141 - val_loss: 1.6586 - val_accuracy: 0.3646
# Epoch 13/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.4864 - accuracy: 0.4222 - val_loss: 1.7643 - val_accuracy: 0.3229
# Epoch 14/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.4657 - accuracy: 0.4427 - val_loss: 1.6714 - val_accuracy: 0.3681
# Epoch 15/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.4435 - accuracy: 0.4511 - val_loss: 1.5353 - val_accuracy: 0.4097
# Epoch 16/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.4024 - accuracy: 0.4552 - val_loss: 1.5807 - val_accuracy: 0.3889
# Epoch 17/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.3910 - accuracy: 0.4751 - val_loss: 1.5569 - val_accuracy: 0.3993
# Epoch 18/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.3432 - accuracy: 0.4974 - val_loss: 1.9729 - val_accuracy: 0.3403
# Epoch 19/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.3361 - accuracy: 0.4957 - val_loss: 1.6579 - val_accuracy: 0.3681
# Epoch 20/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.3073 - accuracy: 0.5067 - val_loss: 1.5939 - val_accuracy: 0.3542
# Epoch 21/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.2924 - accuracy: 0.5168 - val_loss: 1.3681 - val_accuracy: 0.4653
# Epoch 22/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.2492 - accuracy: 0.5339 - val_loss: 1.4530 - val_accuracy: 0.4410
# Epoch 23/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.2236 - accuracy: 0.5460 - val_loss: 1.4313 - val_accuracy: 0.4514
# Epoch 24/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.2318 - accuracy: 0.5333 - val_loss: 1.5082 - val_accuracy: 0.4340
# Epoch 25/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.2023 - accuracy: 0.5469 - val_loss: 1.8760 - val_accuracy: 0.4062
# Epoch 26/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.1642 - accuracy: 0.5703 - val_loss: 1.7512 - val_accuracy: 0.4236
# Epoch 27/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.1388 - accuracy: 0.5689 - val_loss: 1.4091 - val_accuracy: 0.4479
# Epoch 28/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.1345 - accuracy: 0.5802 - val_loss: 1.9142 - val_accuracy: 0.3958
# Epoch 29/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.1039 - accuracy: 0.5891 - val_loss: 1.7274 - val_accuracy: 0.4306
# Epoch 30/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.0877 - accuracy: 0.5894 - val_loss: 1.2487 - val_accuracy: 0.5278
# Epoch 31/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.0596 - accuracy: 0.5992 - val_loss: 1.6854 - val_accuracy: 0.4236
# Epoch 32/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.0441 - accuracy: 0.6088 - val_loss: 1.6002 - val_accuracy: 0.4861
# Epoch 33/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 1.0153 - accuracy: 0.6207 - val_loss: 1.5126 - val_accuracy: 0.4514
# Epoch 34/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.9986 - accuracy: 0.6215 - val_loss: 1.8010 - val_accuracy: 0.3889
# Epoch 35/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.9586 - accuracy: 0.6441 - val_loss: 1.7277 - val_accuracy: 0.4549
# Epoch 36/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.9885 - accuracy: 0.6343 - val_loss: 2.6825 - val_accuracy: 0.3194
# Epoch 37/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.9808 - accuracy: 0.6351 - val_loss: 1.6006 - val_accuracy: 0.4514
# Epoch 38/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.9586 - accuracy: 0.6481 - val_loss: 2.0737 - val_accuracy: 0.3924
# Epoch 39/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.9483 - accuracy: 0.6490 - val_loss: 1.3875 - val_accuracy: 0.5069
# Epoch 40/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.9222 - accuracy: 0.6484 - val_loss: 1.3145 - val_accuracy: 0.4965
# Epoch 41/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.9025 - accuracy: 0.6612 - val_loss: 1.2586 - val_accuracy: 0.5486
# Epoch 42/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.8664 - accuracy: 0.6808 - val_loss: 2.0476 - val_accuracy: 0.4271
# Epoch 43/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.8435 - accuracy: 0.6788 - val_loss: 1.6996 - val_accuracy: 0.4583
# Epoch 44/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.8551 - accuracy: 0.6777 - val_loss: 1.3703 - val_accuracy: 0.5451
# Epoch 45/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.8324 - accuracy: 0.6881 - val_loss: 1.2002 - val_accuracy: 0.5694
# Epoch 46/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.8230 - accuracy: 0.6878 - val_loss: 1.3752 - val_accuracy: 0.5347
# Epoch 47/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.7938 - accuracy: 0.6930 - val_loss: 1.0938 - val_accuracy: 0.5903
# Epoch 48/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.7782 - accuracy: 0.7060 - val_loss: 1.1713 - val_accuracy: 0.6076
# Epoch 49/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.7922 - accuracy: 0.7040 - val_loss: 1.5541 - val_accuracy: 0.4965
# Epoch 50/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.7597 - accuracy: 0.7182 - val_loss: 1.2221 - val_accuracy: 0.5868
# Epoch 51/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.7612 - accuracy: 0.7112 - val_loss: 1.2703 - val_accuracy: 0.5278
# Epoch 52/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.7530 - accuracy: 0.7260 - val_loss: 1.2962 - val_accuracy: 0.5382
# Epoch 53/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.7256 - accuracy: 0.7286 - val_loss: 1.2519 - val_accuracy: 0.5556
# Epoch 54/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.6998 - accuracy: 0.7439 - val_loss: 1.4776 - val_accuracy: 0.5069
# Epoch 55/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.6950 - accuracy: 0.7471 - val_loss: 1.1977 - val_accuracy: 0.5868
# Epoch 56/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.6745 - accuracy: 0.7572 - val_loss: 1.4499 - val_accuracy: 0.5382
# Epoch 57/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.6890 - accuracy: 0.7407 - val_loss: 2.0167 - val_accuracy: 0.4375
# Epoch 58/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.6298 - accuracy: 0.7703 - val_loss: 1.1604 - val_accuracy: 0.6146
# Epoch 59/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.6311 - accuracy: 0.7746 - val_loss: 1.4684 - val_accuracy: 0.5069
# Epoch 60/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.6217 - accuracy: 0.7691 - val_loss: 1.3886 - val_accuracy: 0.5174
# Epoch 61/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.6274 - accuracy: 0.7650 - val_loss: 1.3611 - val_accuracy: 0.5833
# Epoch 62/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.6064 - accuracy: 0.7850 - val_loss: 1.4659 - val_accuracy: 0.5590
# Epoch 63/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.5790 - accuracy: 0.7902 - val_loss: 1.0927 - val_accuracy: 0.6354
# Epoch 64/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.5731 - accuracy: 0.7873 - val_loss: 1.1763 - val_accuracy: 0.5972
# Epoch 65/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.5727 - accuracy: 0.7876 - val_loss: 2.1183 - val_accuracy: 0.4722
# Epoch 66/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.5448 - accuracy: 0.7995 - val_loss: 1.5827 - val_accuracy: 0.4792
# Epoch 67/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.5374 - accuracy: 0.8096 - val_loss: 1.7504 - val_accuracy: 0.5347
# Epoch 68/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.5116 - accuracy: 0.8174 - val_loss: 2.2905 - val_accuracy: 0.4410
# Epoch 69/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.4902 - accuracy: 0.8261 - val_loss: 1.1775 - val_accuracy: 0.6285
# Epoch 70/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.4844 - accuracy: 0.8218 - val_loss: 1.4640 - val_accuracy: 0.5694
# Epoch 71/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.4867 - accuracy: 0.8177 - val_loss: 0.9627 - val_accuracy: 0.6424
# Epoch 72/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.4475 - accuracy: 0.8443 - val_loss: 1.5776 - val_accuracy: 0.5521
# Epoch 73/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.4673 - accuracy: 0.8325 - val_loss: 1.7466 - val_accuracy: 0.5139
# Epoch 74/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.4574 - accuracy: 0.8304 - val_loss: 1.1719 - val_accuracy: 0.6181
# Epoch 75/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.4327 - accuracy: 0.8409 - val_loss: 1.2812 - val_accuracy: 0.6007
# Epoch 76/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.4320 - accuracy: 0.8443 - val_loss: 2.0475 - val_accuracy: 0.4826
# Epoch 77/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.4097 - accuracy: 0.8545 - val_loss: 1.2693 - val_accuracy: 0.5938
# Epoch 78/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.4406 - accuracy: 0.8383 - val_loss: 1.1077 - val_accuracy: 0.6458
# Epoch 79/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.4250 - accuracy: 0.8423 - val_loss: 1.4551 - val_accuracy: 0.5660
# Epoch 80/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.3990 - accuracy: 0.8585 - val_loss: 1.6385 - val_accuracy: 0.5556
# Epoch 81/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.3745 - accuracy: 0.8692 - val_loss: 2.5179 - val_accuracy: 0.4514
# Epoch 82/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.3958 - accuracy: 0.8539 - val_loss: 1.1017 - val_accuracy: 0.6076
# Epoch 83/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.3823 - accuracy: 0.8611 - val_loss: 1.1998 - val_accuracy: 0.6007
# Epoch 84/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.3614 - accuracy: 0.8695 - val_loss: 1.2958 - val_accuracy: 0.6215
# Epoch 85/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.3608 - accuracy: 0.8675 - val_loss: 1.9075 - val_accuracy: 0.5035
# Epoch 86/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.3537 - accuracy: 0.8741 - val_loss: 0.9445 - val_accuracy: 0.6736
# Epoch 87/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.3135 - accuracy: 0.8932 - val_loss: 1.1730 - val_accuracy: 0.5903
# Epoch 88/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.3289 - accuracy: 0.8860 - val_loss: 0.9735 - val_accuracy: 0.6875
# Epoch 89/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.3164 - accuracy: 0.8953 - val_loss: 1.4808 - val_accuracy: 0.5938
# Epoch 90/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.3128 - accuracy: 0.8880 - val_loss: 1.8003 - val_accuracy: 0.5104
# Epoch 91/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.3314 - accuracy: 0.8782 - val_loss: 1.3663 - val_accuracy: 0.6215
# Epoch 92/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.3090 - accuracy: 0.8883 - val_loss: 1.1431 - val_accuracy: 0.6493
# Epoch 93/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.2913 - accuracy: 0.8929 - val_loss: 1.7483 - val_accuracy: 0.5590
# Epoch 94/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.2589 - accuracy: 0.9146 - val_loss: 1.3918 - val_accuracy: 0.6007
# Epoch 95/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.2813 - accuracy: 0.9022 - val_loss: 1.3792 - val_accuracy: 0.5972
# Epoch 96/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.2807 - accuracy: 0.9048 - val_loss: 1.7916 - val_accuracy: 0.5208
# Epoch 97/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.2643 - accuracy: 0.9129 - val_loss: 1.1847 - val_accuracy: 0.6319
# Epoch 98/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.2634 - accuracy: 0.9062 - val_loss: 1.6940 - val_accuracy: 0.5660
# Epoch 99/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.2360 - accuracy: 0.9187 - val_loss: 1.5483 - val_accuracy: 0.5590
# Epoch 100/100
# 3456/3456 [==============================] - 9s 3ms/sample - loss: 0.2520 - accuracy: 0.9152 - val_loss: 1.5837 - val_accuracy: 0.5833

# %%
score = model.evaluate(X_test, y_test, verbose=0)
score
# Out:
# [1.5836615562438965, 0.5833333]

# %%
model.save('speech_emo_model.h5')
model.save_weights('speech_emo_weights.h5')

# %%
model_name = 'Emotion_Model.h5'
save_dir = os.path.join(os.getcwd(), 'saved_models')

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Save model and weights at %s ' % model_path)

# Save the model to disk
model_json = model.to_json()
with open("model_json.json", "w") as json_file:
    json_file.write(model_json)
# Out:
# Save model and weights at /kaggle/working/saved_models/Emotion_Model.h5

# %%
preds = model.predict(X_test)

preds=preds.argmax(axis=1)
preds
# Out:
# array([2, 6, 1, 1, 0, 1, 2, 2, 6, 6, 6, 4, 4, 4, 6, 6, 6, 0, 2, 1, 4, 1,
#        5, 6, 0, 4, 0, 6, 5, 0, 6, 7, 2, 6, 6, 1, 4, 1, 6, 6, 4, 1, 6, 6,
#        2, 6, 7, 4, 4, 0, 6, 1, 6, 0, 4, 4, 3, 2, 6, 5, 1, 6, 2, 0, 3, 6,
#        4, 7, 6, 5, 1, 6, 1, 4, 5, 2, 3, 6, 1, 6, 4, 6, 4, 6, 2, 2, 2, 2,
#        1, 7, 1, 0, 7, 7, 3, 1, 0, 7, 1, 7, 2, 6, 6, 0, 1, 2, 1, 1, 3, 5,
#        2, 6, 6, 6, 3, 7, 2, 6, 4, 0, 6, 5, 6, 1, 4, 7, 1, 0, 0, 6, 7, 0,
#        2, 4, 5, 5, 7, 6, 1, 6, 6, 1, 6, 6, 5, 0, 3, 1, 2, 3, 4, 6, 6, 6,
#        4, 3, 1, 1, 6, 5, 6, 6, 7, 5, 6, 4, 6, 4, 6, 6, 3, 1, 2, 7, 7, 6,
#        1, 4, 1, 7, 1, 6, 1, 2, 3, 3, 1, 4, 0, 6, 0, 5, 6, 6, 4, 5, 2, 6,
#        0, 2, 7, 3, 1, 6, 2, 7, 1, 6, 6, 6, 6, 6, 7, 2, 4, 0, 0, 2, 0, 3,
#        0, 0, 7, 6, 1, 0, 6, 1, 3, 2, 6, 6, 2, 6, 5, 7, 4, 1, 7, 4, 5, 6,
#        1, 4, 1, 5, 6, 5, 6, 4, 1, 1, 6, 4, 6, 6, 3, 6, 4, 6, 6, 6, 6, 1,
#        5, 0, 5, 3, 6, 2, 1, 6, 1, 0, 5, 1, 3, 1, 0, 6, 4, 6, 0, 4, 7, 2,
#        0, 2])

# %%
path_ = '/kaggle/input/ravdess-emotional-speech-audio/Actor_20/03-01-04-02-01-01-20.wav'

# %%
import IPython.display as ipd
ipd.Audio(path_)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
s = []

# Sample rate (16.0 kHz)
sample_rate = 16000     

# Max pad lenght (3.0 sec)
max_pad_len = 49100

X, sample_rate = librosa.load(path_,duration=3,offset=0.5)
sample_rate = np.array(sample_rate)

y = zscore(X)
    
# Padding or truncated signal 
if len(y) < max_pad_len:    
    y_padded = np.zeros(max_pad_len)
    y_padded[:len(y)] = y
    y = y_padded
elif len(y) > max_pad_len:
    y = np.asarray(y[:max_pad_len])

# Add to signal list
s.append(y)

# %%
mel_spect = np.asarray(list(map(mel_spectrogram, s)))

# %%
win_ts = 128
hop_ts = 64

# Split spectrogram into frames
def frame(x, win_step=128, win_size=64):
    nb_frames = 1 + int((x.shape[2] - win_size) / win_step)
    frames = np.zeros((x.shape[0], nb_frames, x.shape[1], win_size)).astype(np.float32)
    for t in range(nb_frames):
        frames[:,t,:,:] = np.copy(x[:,:,(t * win_step):(t * win_step + win_size)]).astype(np.float32)
    return frames

# Frame for TimeDistributed model
x = frame(mel_spect, hop_ts, win_ts)

# %%
x = x.reshape(x.shape[0], x.shape[1] , x.shape[2], x.shape[3], 1)

# %%
preds = model.predict(x)
preds
# Out:
# array([[2.1294614e-05, 4.1704169e-03, 1.4293754e-04, 4.3021581e-01,
#         2.2632888e-04, 8.9077388e-05, 5.6513411e-01, 9.8206172e-09]],
#       dtype=float32)

# %%
preds=preds.argmax(axis=1)
preds
# Out:
# array([6])
